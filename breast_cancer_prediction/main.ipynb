# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
from sklearn import metrics

from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv('data.csv')

data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Refine Dataset

# %%
data.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)

'''
Benign: 양성 (0)
Malignant: 악성 (1)
'''
data['diagnosis'] = data['diagnosis'].map({'B': 0, 'M': 1})

data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
sns.countplot(data['diagnosis'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Split Train and Test

# %%
train, test = train_test_split(data, test_size=0.2, random_state=2019)

x_train = train.drop(['diagnosis'], axis=1)
y_train = train.diagnosis

x_test = test.drop(['diagnosis'], axis=1)
y_test = test.diagnosis

print(len(train), len(test))
# Out:
# 455 114

# %% [markdown]
# # SVM

# %%
model = svm.SVC(gamma='scale')
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('SVM: %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# SVM: 91.23

# %% [markdown]
# # DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('DecisionTreeClassifier: %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# DecisionTreeClassifier: 89.47

# %% [markdown]
# # KNeighborsClassifier

# %%
model = KNeighborsClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('KNeighborsClassifier: %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# KNeighborsClassifier: 92.98

# %% [markdown]
# # LogisticRegression

# %%
model = LogisticRegression(solver='lbfgs', max_iter=2000)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('LogisticRegression: %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# LogisticRegression: 94.74
# c:\Users\RadhaKrishna\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('RandomForestClassifier: %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# RandomForestClassifier: 94.74

# %% [markdown]
# # Compute Feature Importances

# %%
features = pd.Series(
    model.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

print(features)
# Out:
# concave points_worst       0.139633
# perimeter_worst            0.127410
# area_worst                 0.105634
# radius_worst               0.105455
# perimeter_mean             0.080557
# concave points_mean        0.077257
# area_se                    0.051675
# area_mean                  0.051283
# concavity_worst            0.050589
# concavity_mean             0.044085
# radius_mean                0.034087
# compactness_worst          0.016768
# texture_worst              0.015347
# radius_se                  0.012211
# smoothness_worst           0.010990
# texture_mean               0.009069
# compactness_mean           0.008945
# perimeter_se               0.008655
# symmetry_worst             0.006849
# texture_se                 0.005767
# fractal_dimension_mean     0.005060
# fractal_dimension_worst    0.005005
# symmetry_se                0.004484
# fractal_dimension_se       0.004317
# smoothness_mean            0.004055
# smoothness_se              0.003980
# ...

# %% [markdown]
# # Extract Top 5 Features

# %%
top_5_features = features.keys()[:5]

print(top_5_features)
# Out:
# Index(['concave points_worst', 'perimeter_worst', 'area_worst', 'radius_worst',
#        'perimeter_mean'],
#       dtype='object')

# %% [markdown]
# # SVM (Top 5)

# %%
model = svm.SVC(gamma='scale')
model.fit(x_train[top_5_features], y_train)

y_pred = model.predict(x_test[top_5_features])

print('SVM(Top 5): %.2f' % (metrics.accuracy_score(y_pred, y_test) * 100))
# Out:
# SVM(Top 5): 91.23

# %% [markdown]
# # Cross Validaiton (Tedious)

# %%
model = svm.SVC(gamma='scale')

cv = KFold(n_splits=5, shuffle=True, random_state=2019)


accs, scores = [], []

for train_index, test_index in cv.split(data[top_5_features]):
    x_train = data.iloc[train_index][top_5_features]
    y_train = data.iloc[train_index].diagnosis
    
    x_test = data.iloc[test_index][top_5_features]
    y_test = data.iloc[test_index].diagnosis

    model.fit(x_train, y_train)
    
    y_pred = model.predict(x_test)

    accs.append(metrics.accuracy_score(y_test, y_pred))

print(accs)
# Out:
# [0.9122807017543859, 0.9385964912280702, 0.9385964912280702, 0.9210526315789473, 0.8938053097345132]

# %% [markdown]
# # Cross Validation (Simple)

# %%
model = svm.SVC(gamma='scale')

cv = KFold(n_splits=5, shuffle=True, random_state=2019)


accs = cross_val_score(model, data[top_5_features], data.diagnosis, cv=cv)

print(accs)
# Out:
# [0.9122807  0.93859649 0.93859649 0.92105263 0.89380531]

# %% [markdown]
# # Test All Models

# %%
models = {
    'SVM': svm.SVC(gamma='scale'),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'LogisticRegression': LogisticRegression(solver='lbfgs', max_iter=2000),
    'RandomForestClassifier': RandomForestClassifier(n_estimators=100)
}

cv = KFold(n_splits=5, shuffle=True, random_state=2019)


for name, model in models.items():
    scores = cross_val_score(model, data[top_5_features], data.diagnosis, cv=cv)
    
    print('%s: %.2f%%' % (name, np.mean(scores) * 100))
# Out:
# SVM: 92.09%
# DecisionTreeClassifier: 91.92%
# KNeighborsClassifier: 91.38%
# LogisticRegression: 93.32%
# RandomForestClassifier: 94.20%

# %% [markdown]
# # Normalize Dataset

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[top_5_features])

models = {
    'SVM': svm.SVC(gamma='scale'),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'LogisticRegression': LogisticRegression(solver='lbfgs', max_iter=2000),
    'RandomForestClassifier': RandomForestClassifier(n_estimators=100)
}

cv = KFold(n_splits=5, random_state=2019)

for name, model in models.items():
    scores = cross_val_score(model, scaled_data, data.diagnosis, cv=cv)
    
    print('%s: %.2f%%' % (name, np.mean(scores) * 100))
# Out:
# SVM: 93.85%
# DecisionTreeClassifier: 90.68%
# KNeighborsClassifier: 93.15%
# LogisticRegression: 93.85%
# RandomForestClassifier: 93.15%

# %%
import numpy as np
import pandas as pd
from sklearn import metrics, svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the model

# Scaling the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[top_5_features])

# Defining models
models = {
    'SVM': svm.SVC(gamma='scale', probability=True),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'LogisticRegression': LogisticRegression(solver='lbfgs', max_iter=2000),
    'RandomForestClassifier': RandomForestClassifier(n_estimators=100)
}

# Cross-validation
cv = KFold(n_splits=5, shuffle=True, random_state=2019)

# Evaluate individual models
for name, model in models.items():
    scores = cross_val_score(model, scaled_data, data.diagnosis, cv=cv)
    print(f'{name}: {np.mean(scores) * 100:.2f}%')

# Ensemble using Voting Classifier
voting_clf = VotingClassifier(
    estimators=[
        ('svm', models['SVM']),
        ('rf', models['RandomForestClassifier']),
        ('knn', models['KNeighborsClassifier'])
    ],
    voting='soft'  # Soft voting for probabilities
)

# Training the voting classifier
voting_clf.fit(scaled_data, data.diagnosis)

# Cross-validation for ensemble model
ensemble_scores = cross_val_score(voting_clf, scaled_data, data.diagnosis, cv=cv)
print(f'Voting Classifier Accuracy: {np.mean(ensemble_scores) * 100:.2f}%')

# Save the best model
joblib.dump(voting_clf, 'breast_cancer.pkl')
print("Voting Classifier model saved as 'breast_cancer_voting_model.pkl'")
# Out:
# SVM: 94.73%
# DecisionTreeClassifier: 92.09%
# KNeighborsClassifier: 94.38%
# LogisticRegression: 94.38%
# RandomForestClassifier: 94.02%
# Voting Classifier Accuracy: 94.55%
# Voting Classifier model saved as 'breast_cancer_voting_model.pkl'

# %%
# Load the saved model
loaded_model = joblib.load('breast_cancer_voting_model.pkl')

# Example input (replace these values with actual feature data)
# Make sure the input order matches the order of top_5_features
new_data = pd.DataFrame([{
    top_5_features[0]: 0.2,
    top_5_features[1]: 0.4,
    top_5_features[2]: 0.1,
    top_5_features[3]: 0.5,
    top_5_features[4]: 0.3
}])

# Scale the new input data
new_data_scaled = scaler.transform(new_data)

# Make a prediction
prediction = loaded_model.predict(new_data_scaled)
print("Prediction:", prediction)
# Out:
# Prediction: [0]

# %%
import pandas as pd
import joblib
from sklearn.preprocessing import MinMaxScaler

# Load the trained model
loaded_model = joblib.load('breast_cancer.pkl')

# Load the scaler (assuming it was saved earlier; if not, use the same scaling technique)
scaler = joblib.load('scaler.pkl')  # Only if you saved it separately

# Define new test data (Replace values with actual feature values)
# Ensure the order of features matches the `top_5_features`
new_data = pd.DataFrame([{
    'mean_radius': 14.2, 
    'mean_texture': 20.4, 
    'mean_perimeter': 92.1, 
    'mean_area': 600.2, 
    'mean_smoothness': 0.1
}])

# Scale the new input data
new_data_scaled = scaler.transform(new_data)

# Make a prediction
prediction = loaded_model.predict(new_data_scaled)

# Interpret the prediction
result = 'Malignant' if prediction[0] == 1 else 'Benign'
print("Prediction:", result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 9
#       6 loaded_model = joblib.load('breast_cancer.pkl')
#       8 # Load the scaler (assuming it was saved earlier; if not, use the same scaling technique)
# ----> 9 scaler = joblib.load('scaler.pkl')  # Only if you saved it separately
#      11 # Define new test data (Replace values with actual feature values)
#      12 # Ensure the order of features matches the `top_5_features`
#      13 new_data = pd.DataFrame([{
#      14     'mean_radius': 14.2,
#      15     'mean_texture': 20.4,
#    (...)
#      18     'mean_smoothness': 0.1
#      19 }])
#
# File c:\Users\RadhaKrishna\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
# ...

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(data[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean']])
# Out:
# MinMaxScaler()

# %%
import pandas as pd
import joblib
from sklearn.preprocessing import MinMaxScaler

# Load the trained model
loaded_model = joblib.load('breast_cancer.pkl')

# Load the saved scaler (if available)
scaler = joblib.load('scaler.pkl')  # Load only if saved earlier

# Define new test data (replace these values with actual feature values)
# Make sure these feature names match the ones from the training data
new_data = pd.DataFrame([{
    'radius_mean': 14.2,
    'texture_mean': 20.4,
    'perimeter_mean': 92.1,
    'area_mean': 600.2,
    'smoothness_mean': 0.1
}])

# Scale the new input data
new_data_scaled = scaler.transform(new_data)

# Make a prediction
prediction = loaded_model.predict(new_data_scaled)

# Interpret the prediction
result = 'Malignant' if prediction[0] == 'M' else 'Benign'
print("Prediction:", result)
# Out:
# Prediction: Benign

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

# Define and fit the scaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean']])

# Save the scaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# Initialize your models
svm_model = SVC(gamma='scale', probability=True)
dt_model = DecisionTreeClassifier()
knn_model = KNeighborsClassifier()
rf_model = RandomForestClassifier(n_estimators=100)

# Combine models using VotingClassifier
ensemble_model = VotingClassifier(
    estimators=[
        ('SVM', svm_model),
        ('DecisionTree', dt_model),
        ('KNN', knn_model),
        ('RandomForest', rf_model)
    ],
    voting='soft'  # 'hard' for majority voting, 'soft' for probability-based
)

# Train the ensemble model
ensemble_model.fit(x_train, y_train)

# Predict on test data
y_pred = ensemble_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Ensemble Model Accuracy: {accuracy * 100:.2f}%')

# Save the ensemble model
joblib.dump(ensemble_model, 'breast_cancer_ensemble.pkl')
# Out:
# Ensemble Model Accuracy: 92.92%
# ['breast_cancer_ensemble.pkl']
